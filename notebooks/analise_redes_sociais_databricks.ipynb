# %% [markdown]
# # Análise de Comportamento dos Usuários de Redes Sociais
#
# Notebook inicial para execução no Databricks.
#
# Este notebook não armazena tokens ou credenciais. Configure os dados de entrada no seu workspace antes da análise.

# %%
# Teste básico da conexão com o cluster Databricks
print(f'Versão do Spark: {spark.version}')
display(spark.range(5))

# %%
# Verificação opcional do armazenamento acessível pelo workspace
# Descomente e ajuste o caminho quando seus dados estiverem configurados.
# display(dbutils.fs.ls('/Volumes/<catalog>/<schema>/<volume>/'))

# %%
# Exemplo de leitura de dados
# df = spark.read.option('header', True).option('inferSchema', True).csv('/Volumes/<catalog>/<schema>/<volume>/dados.csv')
# display(df.limit(10))
# df.printSchema()

# %% [markdown]
# ## Próximos passos
#
# 1. Conecte este repositório ao Databricks Repos.
# 2. Abra este notebook em um cluster ou SQL Warehouse compatível.
# 3. Configure o caminho do arquivo ou volume com os dados da pesquisa.
# 4. Substitua os exemplos pelas etapas de limpeza, análise e visualização.
